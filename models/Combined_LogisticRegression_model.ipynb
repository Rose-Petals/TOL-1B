# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

# %%
df = pd.read_csv("combined_df.csv")

# %%
df.head(10)
# Out:
#    Unnamed: 0 intake_method           referer    age appointment_location  \
# 0           0          Call  Bariatric Doctor  20-30              Virtual
# 1           1          Call     Family/Friend  10-20              Virtual
# 2           2     Boom Form     Family/Friend  20-30             Freehold
# 3           3     Boom Form     Family/Friend  20-30             Freehold
# 4           4     Boom Form     Family/Friend  30-40             Freehold
# 5           5     Boom Form     Family/Friend  20-30              Virtual
# 6           6     Boom Form     Family/Friend  30-40              Virtual
# 7           7     Boom Form     Family/Friend  20-30              Virtual
# 8           8     Boom Form     Family/Friend  30-40            Princeton
# 9           9     Boom Form     Family/Friend  20-30            Princeton
#
#   appointment_time  Medication_Management  Talk_Therapy
# 0          Evening                      0             1
# 1        Afternoon                      0             1
# 2        Afternoon                      0             1
# 3        Afternoon                      0             1
# 4        Afternoon                      0             1
# 5        Afternoon                      0             1
# 6        Afternoon                      0             1
# 7        Afternoon                      1             0
# 8        Afternoon                      0             1
# 9        Afternoon                      0             1

# %%
df['is_morning'] = (df['appointment_time'].str.lower() == 'morning').astype(int)

# %%
X = df[['intake_method', 'referer', 'age', 'appointment_location']]
y = df['is_morning']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size= .2, random_state = 42)

# %%
df.drop(columns= ['Unnamed: 0'], inplace= True)
df.head()
# Out:
#   intake_method           referer    age appointment_location  \
# 0          Call  Bariatric Doctor  20-30              Virtual
# 1          Call     Family/Friend  10-20              Virtual
# 2     Boom Form     Family/Friend  20-30             Freehold
# 3     Boom Form     Family/Friend  20-30             Freehold
# 4     Boom Form     Family/Friend  30-40             Freehold
#
#   appointment_time  Medication_Management  Talk_Therapy  is_morning
# 0          Evening                      0             1           0
# 1        Afternoon                      0             1           0
# 2        Afternoon                      0             1           0
# 3        Afternoon                      0             1           0
# 4        Afternoon                      0             1           0

# %%
categorical_features = ['intake_method', 'referer', 'age', 'appointment_location']
numeric_features = ['Medication_Management', 'Talk_Therapy']

# %%
preprocessor = ColumnTransformer([('cat', OneHotEncoder(handle_unknown = 'ignore'), categorical_features)], remainder = 'passthrough')

# %%
pipeline = Pipeline([('preprocessor', preprocessor), ('classifier', LogisticRegression(max_iter = 1000))])

# %%
pipeline.fit(X_train ,y_train)
y_pred = pipeline.predict(X_test)

# %%
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n" , confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.98      0.85       267
#            1       0.40      0.04      0.08        89
#
#     accuracy                           0.74       356
#    macro avg       0.58      0.51      0.47       356
# weighted avg       0.67      0.74      0.66       356
#
# Confusion Matrix:
#  [[261   6]
#  [ 85   4]]
